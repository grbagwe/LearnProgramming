# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.linspace(-10, 10, 9) 
# b = 1 / (1 + np.exp(-a))
c= a * np.random.uniform(0, 1 ,(9,)).T

# %%
plt.plot(c)
print(a.shape)
print(c)
# Out:
# (9,)
# [-3.68557735 -0.72749592 -0.1884307  -1.23944873  0.          0.54239597
#   4.54373375  0.48691216  6.89247185]
